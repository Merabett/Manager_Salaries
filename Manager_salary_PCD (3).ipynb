# %% [markdown]
# # Ismail Merabet  (CDIA):    Manager Salary Project

# %% [markdown]
# ## Carga de Librerías

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\ismam\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ismam\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\ismam\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\ismam\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in c:\users\ismam\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ismam\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ismam\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ismam\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ismam\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ismam\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)

# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in c:\users\ismam\anaconda3\lib\site-packages (0.13.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import folium
import requests
from IPython.display import display
import branca.element
import json

# %% [markdown]
# ## Recuperación de DataFrame y obtención de información de los datos

# %% [markdown]
# Link dataset: https://oscarbaruffa.com/messy/

# %%
df = pd.read_csv('ManagerSalarySurvey2021.csv',
                parse_dates=['Timestamp'])

# %%
df.head()
# Out:
#             Timestamp How old are you?  What industry do you work in?  \
# 0 2021-04-27 11:02:10            25-34   Education (Higher Education)
# 1 2021-04-27 11:02:22            25-34              Computing or Tech
# 2 2021-04-27 11:02:38            25-34  Accounting, Banking & Finance
# 3 2021-04-27 11:02:41            25-34                     Nonprofits
# 4 2021-04-27 11:02:42            25-34  Accounting, Banking & Finance
#
#                                   Job title  \
# 0        Research and Instruction Librarian
# 1  Change & Internal Communications Manager
# 2                      Marketing Specialist
# 3                           Program Manager
# 4                        Accounting Manager
#
#   If your job title needs additional context, please clarify here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)  \
# 0                                             55,000
# 1                                             54,600
# 2                                             34,000
# 3                                             62,000
# 4                                             60,000
#
#    How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.  \
# 0                                                0.0
# 1                                             4000.0
# 2                                                NaN
# 3                                             3000.0
# 4                                             7000.0
#
#   Please indicate the currency  \
# 0                          USD
# 1                          GBP
# 2                          USD
# 3                          USD
# 4                          USD
#
#   If "Other," please indicate the currency here:   \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   If your income needs additional context, please provide it here:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What country do you work in?  \
# 0                United States
# 1               United Kingdom
# 2                           US
# 3                          USA
# 4                           US
#
#   If you're in the U.S., what state do you work in? What city do you work in?  \
# 0                                     Massachusetts                    Boston
# 1                                               NaN                 Cambridge
# 2                                         Tennessee               Chattanooga
# 3                                         Wisconsin                 Milwaukee
# 4                                    South Carolina                Greenville
#
#   How many years of professional work experience do you have overall?  \
# 0                                          5-7 years
# 1                                       8 - 10 years
# 2                                        2 - 4 years
# 3                                       8 - 10 years
# 4                                       8 - 10 years
#
#   How many years of professional work experience do you have in your field?  \
# 0                                          5-7 years
# 1                                          5-7 years
# 2                                        2 - 4 years
# 3                                          5-7 years
# 4                                          5-7 years
#
#   What is your highest level of education completed? What is your gender?  \
# 0                                    Master's degree                Woman
# 1                                     College degree           Non-binary
# 2                                     College degree                Woman
# 3                                     College degree                Woman
# 4                                     College degree                Woman
#
#   What is your race? (Choose all that apply.)
# 0                                       White
# 1                                       White
# 2                                       White
# 3                                       White
# 4                                       White

# %%
#df['Timestamp'] = pd.to_datetime(df['Timestamp']).dt.date

# %%
df.columns = ['date', 'age', 'industry', 'occupation', 'job_context', 'annual_salary', 'additional_compensation', 'currency', 'other_currency', 'income_context', 'country', 'state', 'city', 'experience_years_overall', 'experience_years_field', 'highest_education', 'gender', 'race']

# %%
df.head()
# Out:
#                  date    age                       industry  \
# 0 2021-04-27 11:02:10  25-34   Education (Higher Education)
# 1 2021-04-27 11:02:22  25-34              Computing or Tech
# 2 2021-04-27 11:02:38  25-34  Accounting, Banking & Finance
# 3 2021-04-27 11:02:41  25-34                     Nonprofits
# 4 2021-04-27 11:02:42  25-34  Accounting, Banking & Finance
#
#                                  occupation job_context annual_salary  \
# 0        Research and Instruction Librarian         NaN        55,000
# 1  Change & Internal Communications Manager         NaN        54,600
# 2                      Marketing Specialist         NaN        34,000
# 3                           Program Manager         NaN        62,000
# 4                        Accounting Manager         NaN        60,000
#
#    additional_compensation currency other_currency income_context  \
# 0                      0.0      USD            NaN            NaN
# 1                   4000.0      GBP            NaN            NaN
# 2                      NaN      USD            NaN            NaN
# 3                   3000.0      USD            NaN            NaN
# 4                   7000.0      USD            NaN            NaN
#
#           country           state         city experience_years_overall  \
# 0   United States   Massachusetts       Boston                5-7 years
# 1  United Kingdom             NaN    Cambridge             8 - 10 years
# 2              US       Tennessee  Chattanooga              2 - 4 years
# 3             USA       Wisconsin    Milwaukee             8 - 10 years
# 4              US  South Carolina   Greenville             8 - 10 years
#
#   experience_years_field highest_education      gender   race
# 0              5-7 years   Master's degree       Woman  White
# 1              5-7 years    College degree  Non-binary  White
# 2            2 - 4 years    College degree       Woman  White
# 3              5-7 years    College degree       Woman  White
# 4              5-7 years    College degree       Woman  White

# %%
df.shape
# Out:
# (27921, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27921 entries, 0 to 27920
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      27921 non-null  datetime64[ns]
#  1   age                       27921 non-null  object
#  2   industry                  27849 non-null  object
#  3   occupation                27921 non-null  object
#  4   job_context               7225 non-null   object
#  5   annual_salary             27921 non-null  object
#  6   additional_compensation   20677 non-null  float64
#  7   currency                  27921 non-null  object
#  8   other_currency            196 non-null    object
#  9   income_context            3033 non-null   object
#  10  country                   27921 non-null  object
#  11  state                     22944 non-null  object
#  12  city                      27846 non-null  object
#  13  experience_years_overall  27921 non-null  object
#  14  experience_years_field    27921 non-null  object
#  15  highest_education         27710 non-null  object
#  16  gender                    27756 non-null  object
#  17  race                      27753 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(16)
# memory usage: 3.8+ MB

# %%
df.dtypes.value_counts()
# Out:
# object            16
# datetime64[ns]     1
# float64            1
# dtype: int64

# %%
mem_inicial = df.memory_usage(deep = True).sum()
print("{:03.2f} MB".format(mem_inicial/1024**2))
# Out:
# 26.91 MB

# %%
df.industry.nunique()
# Out:
# 1209

# %%
df.occupation.nunique()
# Out:
# 14278

# %%
df.occupation.value_counts()
# Out:
# Software Engineer                286
# Project Manager                  230
# Director                         198
# Senior Software Engineer         196
# Program Manager                  152
#                                 ...
# Middle School Librarian            1
# Executive PA                       1
# Digital Project Specialist         1
# Audit leader                       1
# Director of Content and Brand      1
# Name: occupation, Length: 14278, dtype: int64

# %% [markdown]
# ## Optimización eliminando columnas

# %%
#observamos que hay valores que se consideran distintos por la capitalización de las letras o espacios en blanco sobrantes.

# Selecciona solo las columnas de tipo "object"
object_columns = df.select_dtypes(['object'])

# Convierte todas las filas de las columnas seleccionadas a minúscula y elimina espacios en blanco sobrantes
object_columns = object_columns.applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)

# Actualiza las columnas del DataFrame con los valores actualizados
df[object_columns.columns] = object_columns

# %%
#nos quedamos con los puestos con más de 25 ocurrencias
v = df.occupation.value_counts()
df[df.occupation.isin(v.index[v.gt(25)])]
# Out:
#                      date    age                       industry  \
# 3     2021-04-27 11:02:41  25-34                     nonprofits
# 4     2021-04-27 11:02:42  25-34  accounting, banking & finance
# 7     2021-04-27 11:03:00  25-34  education (primary/secondary)
# 9     2021-04-27 11:03:02  35-44  accounting, banking & finance
# 10    2021-04-27 11:03:03  25-34                     nonprofits
# ...                   ...    ...                            ...
# 27894 2022-11-04 09:12:21  25-34    marketing, advertising & pr
# 27899 2022-11-15 00:08:06  55-64                      insurance
# 27903 2022-11-16 02:55:42  25-34                    social work
# 27911 2022-12-06 11:39:52  35-44                     nonprofits
# 27920 2022-12-22 17:43:19  25-34                  entertainment
#
#                 occupation                                      job_context  \
# 3          program manager                                              NaN
# 4       accounting manager                                              NaN
# 7                librarian                                  high school, ft
# 9        senior accountant                                              NaN
# 10          office manager                                              NaN
# ...                    ...                                              ...
# 27894       data scientist                               very small company
# 27899  executive assistant                                              NaN
# 27903         case manager                                              NaN
# 27911   executive director                                              NaN
# 27920              analyst  analyst in a&r admin department at record label
#
#       annual_salary  additional_compensation currency other_currency  \
# 3            62,000                   3000.0      usd            NaN
# 4            60,000                   7000.0      usd            NaN
# 7            50,000                      NaN      usd            NaN
# 9            45,000                      0.0      usd            NaN
# 10           47,500                      0.0      usd            NaN
# ...             ...                      ...      ...            ...
# 27894         52000                      NaN      usd            NaN
# 27899         92000                      NaN      usd            NaN
# 27903         48000                      NaN      cad            NaN
# 27911        105735                      0.0      usd            NaN
# 27920         60000                      NaN      usd            NaN
#
#                     income_context        country                 state  \
# 3                              NaN            usa             wisconsin
# 4                              NaN             us        south carolina
# 7                              NaN  united states               arizona
# 9      i work for a charter school  united states               florida
# 10                             NaN  united states                   NaN
# ...                            ...            ...                   ...
# 27894                          NaN             us             tennessee
# 27899                          NaN  united states                 texas
# 27903                          NaN         canada                   NaN
# 27911                          NaN  united states  district of columbia
# 27920                          NaN  united states              new york
#
#                  city experience_years_overall experience_years_field  \
# 3           milwaukee             8 - 10 years              5-7 years
# 4          greenville             8 - 10 years              5-7 years
# 7                yuma                5-7 years              5-7 years
# 9          palm coast            21 - 30 years          21 - 30 years
# 10         boston, ma                5-7 years              5-7 years
# ...               ...                      ...                    ...
# 27894       nashville                5-7 years            2 - 4 years
# 27899          dallas            21 - 30 years          11 - 20 years
# 27903         halifax             8 - 10 years         1 year or less
# 27911  washington, dc            21 - 30 years           8 - 10 years
# 27920             nyc              2 - 4 years            2 - 4 years
#
#       highest_education gender                                        race
# 3        college degree  woman                                       white
# 4        college degree  woman                                       white
# 7       master's degree    man                                       white
# 9        college degree  woman  hispanic, latino, or spanish origin, white
# 10       college degree  woman                                       white
# ...                 ...    ...                                         ...
# 27894   master's degree    man                                       white
# 27899    college degree  woman                                       white
# 27903   master's degree  woman                                       white
# 27911   master's degree  woman                                       white
# 27920    college degree  woman                   black or african american
#
# [8106 rows x 18 columns]

# %%
#eliminar las columnas con más de 70% de nulos
null_columns = round((df.isnull().sum()/df.shape[0])*100,2).sort_values(ascending = False)
null_columns
# Out:
# other_currency              99.30
# income_context              89.14
# job_context                 74.12
# additional_compensation     25.94
# state                       17.83
# highest_education            0.76
# race                         0.60
# gender                       0.59
# city                         0.27
# industry                     0.26
# currency                     0.00
# annual_salary                0.00
# age                          0.00
# country                      0.00
# occupation                   0.00
# experience_years_overall     0.00
# experience_years_field       0.00
# date                         0.00
# dtype: float64

# %%
cols_to_drop = null_columns[null_columns >= 70].index
cols_to_drop
# Out:
# Index(['other_currency', 'income_context', 'job_context'], dtype='object')

# %%
df.drop(cols_to_drop, axis = 'columns', inplace = True)

# %%
df.columns
# Out:
# Index(['date', 'age', 'industry', 'occupation', 'annual_salary',
#        'additional_compensation', 'currency', 'country', 'state', 'city',
#        'experience_years_overall', 'experience_years_field',
#        'highest_education', 'gender', 'race'],
#       dtype='object')

# %% [markdown]
# ## Limpieza columna "country"

# %%
#obtenemos aquellos nombres de países con ocurrencia mayor que 5, para así detectar fácilmente variaciones de un mismo país
#por errores de escritura o por otra forma de expresión.
country_occurrences = df.country.value_counts()
df[df.country.isin(country_occurrences.index[country_occurrences.gt(5)])].country.value_counts()
# Out:
# united states               9967
# usa                         9027
# us                          2768
# canada                      1669
# uk                           691
# united kingdom               630
# u.s.                         600
# united states of america     488
# australia                    386
# germany                      193
# england                      169
# ireland                      124
# new zealand                  122
# france                        67
# netherlands                   57
# u.s.a.                        48
# spain                         47
# scotland                      46
# sweden                        41
# switzerland                   38
# belgium                       35
# the netherlands               31
# japan                         29
# denmark                       22
# america                       22
# u.s                           21
# united state                  19
# india                         19
# singapore                     18
# austria                       17
# south africa                  17
# unites states                 17
# finland                       16
# israel                        14
# italy                         14
# norway                        14
# malaysia                      13
# brazil                        11
# u.k.                          11
# united stated                 10
# poland                        10
# u.s.a                          9
# philippines                    8
# u. s.                          7
# mexico                         7
# china                          7
# the united states              7
# united sates                   6
# nz                             6
# thailand                       6
# Name: country, dtype: int64

# %%
df = df[df.country.isin(country_occurrences.index[country_occurrences.gt(5)])]
df["country"] = df["country"].str.strip()

# Crea un diccionario con los patrones y los valores de reemplazo
patterns = {'(^usa$)|(^united states$)|(^united sates$)|(^unites states$)|(^united state$)|(^united stated$)|(^the united states$)|(^america$)|(^u\. s.$)|(^us$)|(^u\.s$)|(^u\.s.$)|(^u\.s.a.$)|(^u\.s.a$)': 'united states of america', 
            '(^u\.k\.$)|(^uk$)|(^england$)': 'united kingdom', 
            '(^nz$)': 'new zealand', 
            '(^netherlands$)': 'netherlands', 
            '(^china$)': "people's republic of china"}

# Utiliza un ciclo para aplicar cada patron y reemplazo
for pattern, replacement in patterns.items():
    df['country'] = df['country'].replace(to_replace=re.compile(pattern, flags=re.IGNORECASE), value=replacement)

# %%
df.country.value_counts()
# Out:
# united states of america      23016
# canada                         1669
# united kingdom                 1501
# australia                       386
# germany                         193
# new zealand                     128
# ireland                         124
# france                           67
# netherlands                      57
# spain                            47
# scotland                         46
# sweden                           41
# switzerland                      38
# belgium                          35
# the netherlands                  31
# japan                            29
# denmark                          22
# india                            19
# singapore                        18
# south africa                     17
# austria                          17
# finland                          16
# israel                           14
# italy                            14
# norway                           14
# malaysia                         13
# brazil                           11
# poland                           10
# philippines                       8
# people's republic of china        7
# mexico                            7
# thailand                          6
# Name: country, dtype: int64

# %%
#observamos que hay ubicaciones de estados unidos donde no se especifica el estado
df[(df.country == 'united states of america') & (df.state.isnull())]
# Out:
#                      date    age                              industry  \
# 10    2021-04-27 11:03:03  25-34                            nonprofits
# 21    2021-04-27 11:03:24  35-44                            nonprofits
# 71    2021-04-27 11:04:39  35-44                 aerospace contracting
# 132   2021-04-27 11:05:46  35-44                     computing or tech
# 133   2021-04-27 11:05:46  55-64          education (higher education)
# ...                   ...    ...                                   ...
# 25207 2021-05-06 10:00:12  25-34                            nonprofits
# 25323 2021-05-06 12:39:18  35-44  government and public administration
# 25599 2021-05-07 01:18:37  25-34                           health care
# 26119 2021-05-12 23:53:52  35-44                       media & digital
# 26494 2021-06-22 11:47:22  35-44         education (primary/secondary)
#
#                                    occupation annual_salary  \
# 10                             office manager        47,500
# 21     program coordinator & assistant editor        50,000
# 71                           project engineer       122,000
# 132                           product manager       130,000
# 133              career services professional        55,000
# ...                                       ...           ...
# 25207                        security analyst         44000
# 25323                   senior fiscal analyst        130000
# 25599                     physician assistant        135000
# 26119                                  editor         45000
# 26494                     high school teacher         56650
#
#        additional_compensation currency                   country state  \
# 10                         0.0      usd  united states of america   NaN
# 21                         NaN      usd  united states of america   NaN
# 71                      3600.0      usd  united states of america   NaN
# 132                        0.0      usd  united states of america   NaN
# 133                        NaN      usd  united states of america   NaN
# ...                        ...      ...                       ...   ...
# 25207                      NaN      usd  united states of america   NaN
# 25323                  25000.0      usd  united states of america   NaN
# 25599                      NaN      usd  united states of america   NaN
# 26119                      0.0      usd  united states of america   NaN
# 26494                   1000.0      usd  united states of america   NaN
#
#                                        city experience_years_overall  \
# 10                               boston, ma                5-7 years
# 21                                  atlanta                5-7 years
# 71                         colorado springs            11 - 20 years
# 132                            philadelphia            11 - 20 years
# 133                            indianapolis            21 - 30 years
# ...                                     ...                      ...
# 25207                        east coast usa              2 - 4 years
# 25323                prefer not to disclose            11 - 20 years
# 25599                           springfield              2 - 4 years
# 26119  fully remote company based out of ca            11 - 20 years
# 26494                          philadelphia                5-7 years
#
#       experience_years_field highest_education gender   race
# 10                 5-7 years    college degree  woman  white
# 21               2 - 4 years               phd  woman  white
# 71             11 - 20 years   master's degree  woman  white
# 132            11 - 20 years    college degree    man  white
# 133            21 - 30 years   master's degree  woman  white
# ...                      ...               ...    ...    ...
# 25207            2 - 4 years   master's degree  woman  white
# 25323          11 - 20 years   master's degree  woman  white
# 25599            2 - 4 years   master's degree  woman  white
# 26119           8 - 10 years    college degree  woman  white
# 26494            2 - 4 years   master's degree  woman  white
#
# [169 rows x 15 columns]

# %%
def fill_state_column(row, us_data):
    state = row['state']
    # Si el país de la fila es Estados Unidos y la columna "state" está vacía
    if row["country"] == "united states of america" and pd.isnull(row["state"]):
        # Comprueba si existe al menos una fila en el dataframe us_data que cumpla la condición us_data["city"] == row["city"]
        if us_data[us_data["city"] == row["city"]].any().any():
            # Si existe, obtiene el estado correspondiente a la ciudad
            state = us_data[us_data["city"] == row["city"]]["state_name"].iloc[0]
        else:
            return state
    return state

# %%
us_data = pd.read_csv('uscities.csv')
us_data["city"] = us_data['city'].str.lower()
us_data["state_name"] = us_data['state_name'].str.lower()

# %%
us_data.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     new york     New York       NY    new york        36081       Queens
# 1  los angeles  Los Angeles       CA  california         6037  Los Angeles
# 2      chicago      Chicago       IL    illinois        17031         Cook
# 3        miami        Miami       FL     florida        12086   Miami-Dade
# 4       dallas       Dallas       TX       texas        48113       Dallas
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18680025  10768.0  shape     False          True
# 1  34.1141 -118.4068    12531334   3267.0  shape     False          True
# 2  41.8375  -87.6866     8586888   4576.0  shape     False          True
# 3  25.7840  -80.2101     6076316   4945.0  shape     False          True
# 4  32.7935  -96.7667     5910669   1522.0  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# 1  America/Los_Angeles        1
# 2      America/Chicago        1
# 3     America/New_York        1
# 4      America/Chicago        1
#
#                                                 zips          id
# 0  11229 11228 11226 11225 11224 11222 11221 1122...  1840034016
# 1  91367 90291 90293 90292 91316 91311 90035 9003...  1840020491
# 2  60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3  33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4  75098 75287 75230 75231 75236 75237 75235 7525...  1840019440

# %%
df["state"] = df.apply(lambda row: fill_state_column(row, us_data), axis=1)

# %%
#aquellas filas donde el país sea estados unidos y el estado sea nulo, las eliminamos.
df = df[~((df.country == 'united states of america') & (df.state.isnull()))]
df.shape
# Out:
# (27536, 15)

# %% [markdown]
# ## Limpieza columna "age"

# %%
df.age.value_counts()
# Out:
# 25-34         12424
# 35-44          9736
# 45-54          3122
# 18-24          1171
# 55-64           981
# 65 or over       92
# under 18         10
# Name: age, dtype: int64

# %%
#convertimos los rangos de la columna age a la mediana de estos.
import re

def convert_age_range(age_range):
    match = re.match(r"(\d+)-(\d+)", age_range)
    if match:
        low, high = match.groups()
        return str((int(low) + int(high)) // 2)
    elif age_range == "under 18":
        return "16"
    elif age_range == "65 or over":
        return "70"
    else:
        return age_range
        
df['age'] = df['age'].apply(convert_age_range)

# %%
df.age.value_counts()
# Out:
# 29    12424
# 39     9736
# 49     3122
# 21     1171
# 59      981
# 70       92
# 16       10
# Name: age, dtype: int64

# %% [markdown]
# ## Limpieza columna "experience_years_field"

# %%
df.experience_years_field.value_counts()
# Out:
# 11 - 20 years       6423
# 5-7 years           6418
# 2 - 4 years         6116
# 8 - 10 years        4897
# 21 - 30 years       1834
# 1 year or less      1431
# 31 - 40 years        379
# 41 years or more      38
# Name: experience_years_field, dtype: int64

# %%
#convertimos los rangos de la columna experience_years_field a la mediana de estos.

def parse_experience(experience):
    # Busca un rango de números en el string
    match = re.search(r'(\d+)\s*-\s*(\d+)', experience)
    if match:
        # Si hay un rango, devuelve la media
        return (int(match.group(1)) + int(match.group(2))) / 2
    elif "or less" in experience:
        return int(experience.split()[0])
    elif "or more" in experience:
        return int(experience.split()[0]) + 5
    else:
        # Si no hay un rango, devuelve el valor
        return int(experience)

df["experience_years_field"] = df['experience_years_field'].apply(parse_experience)

# %%
df.experience_years_field.value_counts()
# Out:
# 15.5    6423
# 6.0     6418
# 3.0     6116
# 9.0     4897
# 25.5    1834
# 1.0     1431
# 35.5     379
# 46.0      38
# Name: experience_years_field, dtype: int64

# %%
df.head()
# Out:
#                  date age                       industry  \
# 0 2021-04-27 11:02:10  29   education (higher education)
# 1 2021-04-27 11:02:22  29              computing or tech
# 2 2021-04-27 11:02:38  29  accounting, banking & finance
# 3 2021-04-27 11:02:41  29                     nonprofits
# 4 2021-04-27 11:02:42  29  accounting, banking & finance
#
#                                  occupation annual_salary  \
# 0        research and instruction librarian        55,000
# 1  change & internal communications manager        54,600
# 2                      marketing specialist        34,000
# 3                           program manager        62,000
# 4                        accounting manager        60,000
#
#    additional_compensation currency                   country           state  \
# 0                      0.0      usd  united states of america   massachusetts
# 1                   4000.0      gbp            united kingdom             NaN
# 2                      NaN      usd  united states of america       tennessee
# 3                   3000.0      usd  united states of america       wisconsin
# 4                   7000.0      usd  united states of america  south carolina
#
#           city experience_years_overall  experience_years_field  \
# 0       boston                5-7 years                     6.0
# 1    cambridge             8 - 10 years                     6.0
# 2  chattanooga              2 - 4 years                     3.0
# 3    milwaukee             8 - 10 years                     6.0
# 4   greenville             8 - 10 years                     6.0
#
#   highest_education      gender   race
# 0   master's degree       woman  white
# 1    college degree  non-binary  white
# 2    college degree       woman  white
# 3    college degree       woman  white
# 4    college degree       woman  white

# %% [markdown]
# ## Convertir todos los salarios a EUR (columna "annual_salary")

# %%
df.currency.unique()
# Out:
# array(['usd', 'gbp', 'cad', 'eur', 'aud/nzd', 'other', 'chf', 'zar',
#        'sek', 'jpy', 'hkd'], dtype=object)

# %%
df['additional_compensation'] = df.additional_compensation.fillna(0)
df.annual_salary.replace(',','', regex=True, inplace=True) #quitamos las comas de los numeros
df['annual_salary'] = df['annual_salary'].astype(float)
df['additional_compensation'] = df['additional_compensation'].astype(float)
df['salary'] = df['annual_salary'] + df['additional_compensation']
df.drop(['annual_salary', 'additional_compensation'], axis = "columns", inplace = True)
#eliminamos las filas cuya currency sea "other"
df.drop(df[df['currency'] == "other"].index, inplace = True)

# %%
df.head()
# Out:
#                  date age                       industry  \
# 0 2021-04-27 11:02:10  29   education (higher education)
# 1 2021-04-27 11:02:22  29              computing or tech
# 2 2021-04-27 11:02:38  29  accounting, banking & finance
# 3 2021-04-27 11:02:41  29                     nonprofits
# 4 2021-04-27 11:02:42  29  accounting, banking & finance
#
#                                  occupation currency  \
# 0        research and instruction librarian      usd
# 1  change & internal communications manager      gbp
# 2                      marketing specialist      usd
# 3                           program manager      usd
# 4                        accounting manager      usd
#
#                     country           state         city  \
# 0  united states of america   massachusetts       boston
# 1            united kingdom             NaN    cambridge
# 2  united states of america       tennessee  chattanooga
# 3  united states of america       wisconsin    milwaukee
# 4  united states of america  south carolina   greenville
#
#   experience_years_overall  experience_years_field highest_education  \
# 0                5-7 years                     6.0   master's degree
# 1             8 - 10 years                     6.0    college degree
# 2              2 - 4 years                     3.0    college degree
# 3             8 - 10 years                     6.0    college degree
# 4             8 - 10 years                     6.0    college degree
#
#        gender   race   salary
# 0       woman  white  55000.0
# 1  non-binary  white  58600.0
# 2       woman  white  34000.0
# 3       woman  white  65000.0
# 4       woman  white  67000.0

# %%
import requests
import xmltodict

# 1. Descargar el archivo XML
url = 'http://www.ecb.europa.eu/stats/eurofxref/eurofxref-daily.xml'
response = requests.get(url)

#2. Parsear el archivo XML para convertirli a un diccionario
xmlstring = response.content
data = xmltodict.parse(xmlstring)

#3. obtener la lista de tasas de cambio
exchange_rates = data['gesmes:Envelope']['Cube']['Cube']['Cube']
exchange_rates = pd.DataFrame(exchange_rates)
exchange_rates['@currency'] = exchange_rates['@currency'].str.lower()
exchange_rates = exchange_rates.set_index('@currency')['@rate'].astype(float)

#observamos la estructura resultante
exchange_rates
# Out:
# @currency
# usd        1.08650
# jpy      141.10000
# bgn        1.95580
# czk       23.82600
# dkk        7.43780
# gbp        0.87885
# huf      388.85000
# pln        4.70850
# ron        4.89650
# sek       11.21080
# chf        1.00170
# isk      154.90000
# nok       10.76000
# try       20.43650
# aud        1.52890
# brl        5.51040
# cad        1.44790
# cny        7.36900
# hkd        8.50610
# idr    16281.15000
# ils        3.73530
# inr       88.67200
# krw     1341.37000
# mxn       20.36780
# myr        4.61160
# nzd        1.67590
# php       59.18700
# sgd        1.42770
# thb       35.70200
# zar       18.71850
# Name: @rate, dtype: float64

# %%
# 4. Crear una nueva columna llamada "salary_eur" en el DataFrame df
df['salary_eur'] = 0.0

#5. Para cada fila del DataFrame df, convertir el salario a euros
df['salary_eur'] = df.apply(lambda x: round(x['salary']/ exchange_rates.get(x['currency'],1),2) if x['currency'] in exchange_rates.index else x['salary'], axis=1)

# %%
#borramos algunas columnas que no vamos a utilizar
df.drop(['currency','experience_years_overall', 'salary'], axis = "columns", inplace = True)

# %%
df.head()
# Out:
#                  date age                       industry  \
# 0 2021-04-27 11:02:10  29   education (higher education)
# 1 2021-04-27 11:02:22  29              computing or tech
# 2 2021-04-27 11:02:38  29  accounting, banking & finance
# 3 2021-04-27 11:02:41  29                     nonprofits
# 4 2021-04-27 11:02:42  29  accounting, banking & finance
#
#                                  occupation                   country  \
# 0        research and instruction librarian  united states of america
# 1  change & internal communications manager            united kingdom
# 2                      marketing specialist  united states of america
# 3                           program manager  united states of america
# 4                        accounting manager  united states of america
#
#             state         city  experience_years_field highest_education  \
# 0   massachusetts       boston                     6.0   master's degree
# 1             NaN    cambridge                     6.0    college degree
# 2       tennessee  chattanooga                     3.0    college degree
# 3       wisconsin    milwaukee                     6.0    college degree
# 4  south carolina   greenville                     6.0    college degree
#
#        gender   race  salary_eur
# 0       woman  white    50621.26
# 1  non-binary  white    66678.05
# 2       woman  white    31293.14
# 3       woman  white    59825.13
# 4       woman  white    61665.90

# %% [markdown]
# ## Limpieza columna "race"

# %%
df.race.value_counts()
# Out:
# white                                                                                                                            22811
# asian or asian american                                                                                                           1319
# black or african american                                                                                                          648
# another option not listed here or prefer not to answer                                                                             591
# hispanic, latino, or spanish origin                                                                                                567
# hispanic, latino, or spanish origin, white                                                                                         374
# asian or asian american, white                                                                                                     340
# black or african american, white                                                                                                   121
# middle eastern or northern african, white                                                                                           79
# middle eastern or northern african                                                                                                  66
# native american or alaska native, white                                                                                             66
# white, another option not listed here or prefer not to answer                                                                       63
# native american or alaska native                                                                                                    42
# black or african american, hispanic, latino, or spanish origin                                                                      26
# asian or asian american, hispanic, latino, or spanish origin, white                                                                 14
# asian or asian american, hispanic, latino, or spanish origin                                                                        14
# black or african american, hispanic, latino, or spanish origin, white                                                               11
# hispanic, latino, or spanish origin, native american or alaska native                                                                9
# hispanic, latino, or spanish origin, native american or alaska native, white                                                         9
# asian or asian american, another option not listed here or prefer not to answer                                                      9
# asian or asian american, black or african american                                                                                   8
# asian or asian american, middle eastern or northern african                                                                          7
# asian or asian american, black or african american, white                                                                            6
# hispanic, latino, or spanish origin, another option not listed here or prefer not to answer                                          6
# asian or asian american, white, another option not listed here or prefer not to answer                                               6
# black or african american, middle eastern or northern african, white                                                                 5
# black or african american, native american or alaska native, white                                                                   5
# hispanic, latino, or spanish origin, middle eastern or northern african, white                                                       5
# asian or asian american, native american or alaska native, white                                                                     4
# black or african american, hispanic, latino, or spanish origin, native american or alaska native, white                              3
# black or african american, another option not listed here or prefer not to answer                                                    2
# hispanic, latino, or spanish origin, middle eastern or northern african                                                              2
# middle eastern or northern african, white, another option not listed here or prefer not to answer                                    2
# black or african american, middle eastern or northern african                                                                        2
# middle eastern or northern african, native american or alaska native, white                                                          1
# asian or asian american, hispanic, latino, or spanish origin, another option not listed here or prefer not to answer                 1
# middle eastern or northern african, native american or alaska native                                                                 1
# asian or asian american, native american or alaska native                                                                            1
# hispanic, latino, or spanish origin, native american or alaska native, another option not listed here or prefer not to answer        1
# asian or asian american, middle eastern or northern african, white                                                                   1
# hispanic, latino, or spanish origin, white, another option not listed here or prefer not to answer                                   1
# asian or asian american, black or african american, native american or alaska native, white                                          1
# asian or asian american, black or african american, hispanic, latino, or spanish origin                                              1
# black or african american, middle eastern or northern african, native american or alaska native, white                               1
# asian or asian american, hispanic, latino, or spanish origin, native american or alaska native, white                                1
# native american or alaska native, white, another option not listed here or prefer not to answer                                      1
# native american or alaska native, another option not listed here or prefer not to answer                                             1
# asian or asian american, hispanic, latino, or spanish origin, white, another option not listed here or prefer not to answer          1
# Name: race, dtype: int64

# %%
df.race.dtype
# Out:
# dtype('O')

# %%
import re

def simplify_race(row):
    race_list = ['white', 'asian', 'black', 'hispanic', 'native american', 'middle eastern', 'other']
    for race in race_list:
        if re.search(race, row):
            row = race
            break
    return row

df['race'] = df['race'].astype(str).apply(simplify_race)

# %%
df.race.value_counts()
# Out:
# white              23932
# asian               1360
# black                678
# other                591
# hispanic             585
# nan                  158
# middle eastern        66
# native american       44
# Name: race, dtype: int64

# %% [markdown]
# ## Limpieza columna "gender"

# %%
df.gender.value_counts()
# Out:
# woman                            20945
# man                               5289
# non-binary                         738
# other or prefer not to answer      280
# prefer not to answer                 1
# Name: gender, dtype: int64

# %%
df = df[df.gender.isin(['woman', 'man'])]

# %%
df.gender.value_counts()
# Out:
# woman    20945
# man       5289
# Name: gender, dtype: int64

# %%
df.highest_education.value_counts()
# Out:
# college degree                        12664
# master's degree                        8333
# some college                           1887
# phd                                    1349
# professional degree (md, jd, etc.)     1259
# high school                             580
# Name: highest_education, dtype: int64

# %%
df.head()
# Out:
#                  date age                       industry  \
# 0 2021-04-27 11:02:10  29   education (higher education)
# 2 2021-04-27 11:02:38  29  accounting, banking & finance
# 3 2021-04-27 11:02:41  29                     nonprofits
# 4 2021-04-27 11:02:42  29  accounting, banking & finance
# 5 2021-04-27 11:02:46  29   education (higher education)
#
#                            occupation                   country  \
# 0  research and instruction librarian  united states of america
# 2                marketing specialist  united states of america
# 3                     program manager  united states of america
# 4                  accounting manager  united states of america
# 5      scholarly publishing librarian  united states of america
#
#             state         city  experience_years_field highest_education  \
# 0   massachusetts       boston                     6.0   master's degree
# 2       tennessee  chattanooga                     3.0    college degree
# 3       wisconsin    milwaukee                     6.0    college degree
# 4  south carolina   greenville                     6.0    college degree
# 5   new hampshire      hanover                     3.0   master's degree
#
#   gender   race  salary_eur
# 0  woman  white    50621.26
# 2  woman  white    31293.14
# 3  woman  white    59825.13
# 4  woman  white    61665.90
# 5    man  white    57063.97

# %% [markdown]
# # Visualización

# %%
countries = df.country.unique().tolist()
print(countries)
# Out:
# ['united states of america', 'canada', 'united kingdom', 'scotland', 'the netherlands', 'australia', 'spain', 'finland', 'france', 'ireland', 'denmark', 'netherlands', 'switzerland', 'germany', 'mexico', 'south africa', 'belgium', 'sweden', 'japan', 'austria', 'new zealand', "people's republic of china", 'india', 'israel', 'italy', 'norway', 'malaysia', 'singapore', 'brazil', 'philippines', 'poland', 'thailand']

# %%
with open("ne_110m_admin_0_countries.geojson", "r", encoding="utf-8") as f:
    geojson = json.load(f)

    # Crea una nueva lista para almacenar los elementos del archivo GeoJSON que cumplan la condición
filtered_features = []

# Recorre cada elemento del archivo GeoJSON
for feature in geojson['features']:
    # Si el nombre del país está en la lista de países, añade el elemento a la lista filtered_features
    if feature['properties']['NAME_EN'].lower() in countries:
        # Convierte el nombre del país a minúsculas y lo asigna a la clave 'name'
        feature['properties']['NAME_EN'] = feature['properties']['NAME_EN'].lower()
        filtered_features.append(feature)

#Asigna la lista filtered_features a la clave 'features' del archivo GeoJSON
geojson['features'] = filtered_features

# %%
for feature in geojson['features']:
    print(feature['properties']['NAME_EN'])
# Out:
# canada
# united states of america
# norway
# south africa
# mexico
# brazil
# france
# israel
# thailand
# india
# sweden
# poland
# austria
# germany
# switzerland
# belgium
# netherlands
# spain
# ireland
# new zealand
# australia
# people's republic of china
# italy
# denmark
# united kingdom
# philippines
# malaysia
# finland
# japan

# %%
# Agrupa el dataframe por país y calcula el promedio de salarios
df_grouped = df.groupby('country')['salary_eur'].mean().reset_index()
df_grouped
# Out:
#                        country     salary_eur
# 0                    australia  112502.644986
# 1                      austria   53800.000000
# 2                      belgium   71292.774571
# 3                       brazil   85411.870000
# 4                       canada   61472.444642
# 5                      denmark  189990.298000
# 6                      finland   39993.062500
# 7                       france   57147.581406
# 8                      germany   79249.277135
# 9                        india  199744.760000
# 10                     ireland   69758.859060
# 11                      israel  157346.654286
# 12                       italy   47510.160000
# 13                       japan   62931.851481
# 14                    malaysia   18713.760000
# 15                      mexico   94569.717500
# 16                 netherlands   68353.388750
# 17                 new zealand  106510.464188
# 18                      norway  387976.925000
# 19  people's republic of china  101909.955000
# 20                 philippines   91118.270000
# 21                      poland  115048.320000
# 22                    scotland   42344.922558
# 23                   singapore  412018.406667
# 24                south africa   45069.561875
# 25                       spain   44999.316744
# 26                      sweden   47356.958421
# 27                 switzerland  122479.302647
# 28                    thailand   53842.613333
# 29             the netherlands   59539.877097
# 30              united kingdom   62185.626205
# 31    united states of america   93839.704231

# %%
countries = []
for feature in geojson['features']:
    countries.append(feature['properties']['NAME_EN'])

# Crea un mapa
m = folium.Map()

# Define la función que determina el color de cada país en función del salario
#los paises con salario mayor que 100000 se colorean de verde, los de salario entre 50000 y 99999 de amarillo y el resto de rojo
def get_color(salary):
    if salary > 100000:
        return 'green'
    elif salary > 50000:
        return 'yellow'
    else:
        return 'red'

# Define la función que asigna el color a cada feature
def style_function(feature):
    # Obtiene el nombre del país y el salario del DataFrame
    country = df_grouped[df_grouped['country'] == feature['properties']['NAME_EN']]['country'].values[0]
    salary = df_grouped[df_grouped['country'] == feature['properties']['NAME_EN']]['salary_eur'].values[0]
    
    # Asigna el color gris a los países que no estén en el DataFrame
    if country not in df_grouped['country'].values:
        return {
            'fillColor': 'grey',
            'color': 'black',
            'weight': 2,
            'dashArray': '5, 5'
        }
    # Asigna el color correspondiente a los países del DataFrame
    else:
        return {
            'fillColor': get_color(salary),
            'color': 'black',
            'weight': 2,
            'dashArray': '5, 5'
        }

#Añade una capa al mapa con todos los países del GeoJSON
folium.GeoJson(
    geojson,
    style_function=style_function
    ).add_to(m)


display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d597d819d8fa7e32643f749c96a270a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d597d819d8fa7e32643f749c96a270a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d597d819d8fa7e32643f749c96a270a = L.map(
#                 &quot;map_0d597d819d8fa7e32643f749c96a270a&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_814e46c055181beaa23e10a245a17c42 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d597d819d8fa7e32643f749c96a270a);
#
#
#         function geo_json_6a8b933bcf4f744afee00c6e7a50b0c1_styler(feature) {
#             switch(feature.properties.SOVEREIGNT) {
#                 case &quot;Norway&quot;: case &quot;Israel&quot;: case &quot;India&quot;: case &quot;Poland&quot;: case &quot;Switzerland&quot;: case &quot;New Zealand&quot;: case &quot;Australia&quot;: case &quot;China&quot;: case &quot;Denmark&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;green&quot;, &quot;weight&quot;: 2};
#                 case &quot;South Africa&quot;: case &quot;Sweden&quot;: case &quot;Spain&quot;: case &quot;Italy&quot;: case &quot;Malaysia&quot;: case &quot;Finland&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_6a8b933bcf4f744afee00c6e7a50b0c1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6a8b933bcf4f744afee00c6e7a50b0c1 = L.geoJson(null, {
#                 onEachFeature: geo_json_6a8b933bcf4f744afee00c6e7a50b0c1_onEachFeature,
#
#                 style: geo_json_6a8b933bcf4f744afee00c6e7a50b0c1_styler,
#         });
#
#         function geo_json_6a8b933bcf4f744afee00c6e7a50b0c1_add (data) {
#             geo_json_6a8b933bcf4f744afee00c6e7a50b0c1
#                 .addData(data)
#                 .addTo(map_0d597d819d8fa7e32643f749c96a270a);
#         }
#             geo_json_6a8b933bcf4f744afee00c6e7a50b0c1_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-122.84, 49.000000000000114], [-122.97421, 49.00253777777778], [-124.91024, 49.98456], [-125.62461, 50.41656], [-127.43561, 50.83061], [-127.99276, 51.71583], [-127.85032, 52.32961], [-129.12979, 52.75538], [-129.30523, 53.56159], [-130.51497, 54.28757], [-130.53610895273684, 54.80275447679924], [-130.53611, 54.80278], [-129.98, 55.285], [-130.00778, 55.91583], [-131.70781, 56.55212], [-132.73042, 57.69289], [-133.35556, 58.41028], [-134.27111, 58.86111], [-134.945, 59.2705600000001], [-135.47583, 59.78778], [-136.47972, 59.46389], [-137.4525, 58.905], [-138.34089, 59.56211], [-139.039, 60.0], [-140.013, 60.27682], [-140.99778, 60.30639], [-140.9925, 66.00003], [-140.986, 69.712], [-140.98598761037601, 69.71199839952635], [-139.12052, 69.47102], [-137.54636, 68.99002], [-136.50358, 68.89804], [-135.62576, 69.31512], [-134.41464, 69.62743], [-132.92925, 69.50534], [-131.43136, 69.94451], [-129.79471, 70.19369], [-129.10773, 69.77927], [-128.36156, 70.01286], [-128.13817, 70.48384], [-127.44712, 70.37721], [-125.75632, 69.48058], [-124.42483, 70.1584], [-124.28968, 69.39969], [-123.06108, 69.56372], [-122.6835, 69.85553], [-121.47226, 69.79778], [-119.94288, 69.37786], [-117.60268, 69.01128], [-116.22643, 68.84151], [-115.2469, 68.90591], [-113.89794, 68.3989], [-115.30489, 67.90261], [-113.49727, 67.68815], [-110.798, 67.80612], [-109.94619, 67.98104], [-108.8802, 67.38144], [-107.79239, 67.88736], [-108.81299, 68.31164], [-108.16721, 68.65392], [-106.95, 68.7], [-106.15, 68.8], [-105.34282, 68.56122], [-104.33791, 68.018], [-103.22115, 68.09775], [-101.45433, 67.64689], [-99.90195, 67.80566], [-98.4432, 67.78165], [-98.5586, 68.40394], [-97.66948, 68.57864], [-96.11991, 68.23939], [-96.12588, 67.29338], [-95.48943, 68.0907], [-94.685, 68.06383], [-94.23282, 69.06903], [-95.30408, 69.68571], [-96.47131, 70.08976], [-96.39115, 71.19482], [-95.2088, 71.92053], [-93.88997, 71.76015], [-92.87818, 71.31869], [-91.51964, 70.19129], [-92.40692, 69.69997], [-90.5471, 69.49766], [-90.55151, 68.47499], [-89.21515, 69.25873], [-88.01966, 68.615

# %% [markdown]
# En la gráfica anterior se puede apreciar qué países tienen un salario alto, medio o bajo, siendo estos coloreados de color verde, amarillo o rojo respectivamente según su salario medio. Observamos que los países con mejores sueldos son algunos países al norte de europa como Dinamarca y suiza, países asiáticos como China o Singapore; y Oceanía. Por otro lado, entre los países con peores salarios podemos encontrar a España, Italia y Sudáfrica.

# %%
sns.barplot(x='race', y='salary_eur', hue='gender', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observamos que la raza con mejor salario medio es la asiática, seguida de oriente medio y blancos.

# %%
ax = sns.barplot(x='country', y='salary_eur', data=df_grouped.sort_values(by='salary_eur', ascending=False).head())
ax.set_title("TOP 5 países con mejor salario")
ax
# Out:
# <AxesSubplot:title={'center':'TOP 5 países con mejor salario'}, xlabel='country', ylabel='salary_eur'>

# %%
sns.countplot(x='race', hue='highest_education', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# La gráfica anterior representa el nivel de estudios más alto por cada raza. Se observa que la raza "white", seguramente debido a que la gran mayoría de trabajadores del dataset son de estados unidos, es la que más predominante. Naturalmente, hay más cantidad de graduados universitarios que personas con máster, ya que para llegar al máster necesariamente debes pasar por la universidad. Resulta curioso aunque lógico que el número de doctorados sea muy bajo.

# %%
# Crea una figura con 2 subplots
fig, ax = plt.subplots(1, 2, figsize=(25, 20))

# Gráfico de pastel para la columna 'race'
df['race'].value_counts().plot.pie(ax=ax[0], title='Race', legend=True, fontsize=0)

# Gráfico de pastel para la columna 'highest_education'
df['highest_education'].value_counts().plot.pie(ax=ax[1], title='Highest Education', legend=True, fontsize=0)

# Muestra la figura
plt.show()

# %% [markdown]
# El pie chart de la izquierda representa el número de personas de cada raza en el dataset, observando que la gran mayoría se consideran "white", seguidos de la raza asiática. Aunque pueda parecer que la raza "native american" es la menos popular, no es cierto, lo que ocurre es que los estadounidenses tienden a autollamarse "blancos" en vez de "estadounidenses".
#
# En el pie chart de la derecha se analiza los estudios más altos de la población donde, como hemos visto en la gráfica anterior, predominan la universidad y el máster. En la gráfica siguiente veremos si las personas con niveles altos de estudio son aquellas con mejores salarios.

# %%
grouped_by_education = df.groupby('highest_education')['salary_eur'].mean().reset_index()
ax = sns.barplot(x='highest_education', y='salary_eur', data=grouped_by_education)
ax.set_title("Salario según nivel de educación")
plt.xticks(rotation=45)
plt.show()
ax
# Out:
# <AxesSubplot:title={'center':'Salario según nivel de educación'}, xlabel='highest_education', ylabel='salary_eur'>

# %% [markdown]
# En la gráfica anterior, observamos que aunque los estudios universitarios y de máster sean los más predominantes como hemos visto en los pie charts, las personas con mejores salarios son aquellas que han realizado algún estudios o trabajos profesionales más enfocados al mundo laboral, lo que sería equivalente a Formación Profesional (FP) en España.

# %%
df['date'] = pd.to_datetime(df['date']).dt.to_period('M')
df_grouped_date = df.groupby('date')['salary_eur'].mean().reset_index()
df_grouped_date
# Out:
#        date     salary_eur
# 0   2021-04   89632.652790
# 1   2021-05   91092.542162
# 2   2021-06  137424.902870
# 3   2021-07  102562.573380
# 4   2021-08   90221.367385
# 5   2021-09   81749.257600
# 6   2021-10   86109.568554
# 7   2021-11   82916.311528
# 8   2021-12   86528.157021
# 9   2022-01   76870.346739
# 10  2022-02  112539.270000
# 11  2022-03   84733.742778
# 12  2022-04   93674.536977
# 13  2022-05   83091.244333
# 14  2022-06   74474.857083
# 15  2022-07   84501.265000
# 16  2022-08   72217.284706
# 17  2022-09   72832.160000
# 18  2022-10   81737.620909
# 19  2022-11   94622.093333
# 20  2022-12   73382.291818

# %%
chart = sns.barplot(x='date', y='salary_eur', data=df_grouped_date)
plt.title('Progreso del salario en el tiempo')
plt.xlabel('Fecha')
plt.ylabel('Salario')
chart.set_xticklabels(chart.get_xticklabels(),rotation=30)
plt.figure(figsize=(25, 20))
plt.show()
